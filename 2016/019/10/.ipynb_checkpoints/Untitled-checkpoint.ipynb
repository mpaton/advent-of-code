# %%
import pandas as pd
import numpy as np
import math
import collections
import re

# %%
data = pd.read_csv('./example.txt',header=None,delim_whitespace=False)

lines = data.values

print len(lines)
print len(lines)

test = (5,7)
print test
# Out:
# 6
# 6
# (5, 7)
# 1

# %%
data = pd.read_csv('./example.txt',header=None,delim_whitespace=False)
    
    
# assign chips to bots first
bots = {}
lines = data[0].values
lines_to_delete = []
for idx in range(len(lines)):
    line = lines[idx]
    if "value" in line:
        instructions = line.split(" ")
        bot = instructions[5]
        chipvalue = int(instructions[1])
        if bot in bots.keys():
            chips = bots[bot]
            if chips[0] == -1:
                bots[bot] = (chipvalue,chips[1])
            else:
                bots[bot] = (chips[0],chipvalue)
        else:
            bots[bot] = (chipvalue,-1)
        lines_to_delete.append(idx)

lines = np.delete(lines, lines_to_delete, axis=0)

# %%
data = pd.read_csv('./input.txt',header=None,delim_whitespace=False)
    
    
# assign chips to bots first
bots = {}
lines = data[0].values
lines_to_delete = []
for idx in range(len(lines)):
    line = lines[idx]
    if "value" in line:
        instructions = line.split(" ")
        bot = instructions[5]
        chipvalue = int(instructions[1])
        if bot in bots.keys():
            chips = bots[bot]
            if chips[0] == -1:
                bots[bot] = (chipvalue,chips[1])
            else:
                bots[bot] = (chips[0],chipvalue)
        else:
            bots[bot] = (chipvalue,-1)
        lines_to_delete.append(idx)

lines = np.delete(lines, lines_to_delete, axis=0)

# follow instructions
output0 = []
output1 = []
output2 = []


finished = False

lines_to_delete = []
while finished == False:
    finished = len(lines) < 6
    print "round!!"
    print len(lines)
    lines_to_delete = []
    for idx in range(len(lines)):
        line = lines[idx]
        if "gives" in line:
            instructions = line.split(" ")
            giving_bot = instructions[1]
            if giving_bot not in bots:
                continue
                
            chips = bots[giving_bot]
            low_chip = min(chips)
            high_chip = max(chips)
            
            if low_chip == -1 or high_chip == -1:
                continue
    
            lines_to_delete.append(idx)
            if low_chip == 17 and high_chip == 61:
                print "THIS IS THE BOT YOU ARE LOOKING FOR" + giving_bot

            ## low instructions
            low_instructions = line.split("and")[0].split(" ")
            if(low_instructions[5] == "output"):
                output = low_instructions[6]
                if output == "0":
                    output0.append(low_chip)
                elif output == "1":
                    output1.append(low_chip)
                elif output == "2":
                    output2.append(low_chip)
            else:
                recv_bot = low_instructions[6]
                if recv_bot not in bots:
                    bots[recv_bot] = (-1,-1)

                recv_chips = bots[recv_bot]
                if recv_chips[0] ==  -1:
                    bots[recv_bot] = (low_chip,recv_chips[1])
                elif recv_chips[1] == -1:
                    bots[recv_bot] = (recv_chips[0],low_chip)


            high_instructions = line.split("and")[1].split(" ")
            if(high_instructions[3] == "output"):
                output = high_instructions[4]
                if output == "0":
                    output0.append(high_chip)
                elif output == "1":
                    output1.append(high_chip)
                elif output == "2":
                    output2.append(high_chip)
            else:
                recv_bot = high_instructions[4]
                if recv_bot not in bots:
                    bots[recv_bot] = (-1,-1)

                recv_chips = bots[recv_bot]
                if recv_chips[0] ==  -1:
                    bots[recv_bot] = (high_chip,recv_chips[1])
                elif recv_chips[1] == -1:
                    bots[recv_bot] = (recv_chips[0],high_chip)
            bots[giving_bot] = {-1,-1}
    ## instruction completed, remove from lines
    print lines_to_delete
    lines = np.delete(lines, lines_to_delete, axis=0)

print lines

print "BOTS"
for key, value in bots.iteritems():
    print key,value
# Out:
# round!!
# 210
# bot 104 gives low to bot 162 and high to bot 189
# ['', 'high', 'to', 'bot', '189']
# [118]
# round!!
# 209
# bot 162 gives low to bot 114 and high to bot 189
# ['', 'high', 'to', 'bot', '189']
# [117]
# round!!
# 208
# bot 114 gives low to bot 140 and high to bot 51
# ['', 'high', 'to', 'bot', '51']
# bot 189 gives low to bot 51 and high to bot 62
# ['', 'high', 'to', 'bot', '62']
# bot 140 gives low to bot 110 and high to bot 181
# ['', 'high', 'to', 'bot', '181']
# bot 51 gives low to bot 181 and high to bot 62
# ['', 'high', 'to', 'bot', '62']
# [5, 83, 162, 174]
# round!!
# 204
# bot 62 gives low to bot 58 and high to bot 120
# ['', 'high', 'to', 'bot', '120']
# bot 110 gives low to bot 115 and high to bot 48
# ['', 'high', 'to', 'bot', '48']
# bot 181 gives low to bot 48 and high to bot 58
# ['', 'high', 'to', 'bot', '58']
# bot 58 gives low to bot 160 and high to bot 120
# ['', 'high', 'to', 'bot', '120']
# [65, 90, 137, 164]
# round!!
# 200
# bot 48 gives low to bot 151 and high to bot 160
# ['', 'high', 'to', 'bot', '160']
# bot 115 gives low to bot 24 and high to bot 151
# ['', 'high', 'to', 'bot', '151']
# bot 160 gives low to bot 123 and high to bot 112
# ['', 'high', 'to', 'bot', '112']
# bot 120 gives low to bot 112 and high to bot 198
# ['', 'high', 'to', 'bot', '198']
# bot 112 gives low to bot 61 and high to bot 198
# ['', 'high', 'to', 'bot', '198']
# bot 198 gives low to bot 144 and high to bot 79
# ['', 'high', 'to', 'bot', '79']
# bot 24 gives low to bot 74 and high to bot 137
# ['', 'high', 'to', 'bot', '137']
# bot 74 gives low to bot 45 and high to bot 69
# ['', 'high', 'to', 'bot', '69']
# bot 151 gives low to bot 137 and high to bot 123
# ['', 'high', 'to', 'bot', '123']
# [16, 66, 83, 94, 124, 129, 153, 190, 198]
# round!!
# 191
# bot 45 gives low to bot 195 and high to bot 13
# ['', 'high', 'to', 'bot', '13']
# bot 195 gives low to bot 165 and high to bot 31
# ['', 'high', 'to', 'bot', '31']
# bot 123 gives low to bot 35 and high to bot 61
# ['', 'high', 'to', 'bot', '61']
# bot 137 gives low to bot 69 and high to bot 35
# ['', 'high', 'to', 'bot', '35']
# [55, 107, 172, 174]
# round!!
# 187
# bot 61 gives low to bot 171 and high to bot 144
# ['', 'high', 'to', 'bot', '144']
# bot 165 gives low to bot 27 and high to bot 72
# ['', 'high', 'to', 'bot', '72']
# bot 144 gives low to bot 23 and high to bot 79
# ['', 'high', 'to', 'bot', '79']
# bot 27 gives low to bot 3 and high to bot 97
# ['', 'high', 'to', 'bot', '97']
# bot 3 gives low to bot 19 and high to bot 207
# ['', 'high', 'to', 'bot', '207']
# bot 35 gives low to bot 122 and high to bot 171
# ['', 'high', 'to', 'bot', '171']
# bot 69 gives low to bot 13 and high to bot 122
# ['', 'high', 'to', 'bot', '122']
# bot 79 gives low to bot 42 and high to bot 191
# ['', 'high', 'to', 'bot', '191']
# bot 122 gives low to bot 9 and high to bot 201
# ['', 'high', 'to', 'bot', '201']
# [50, 62, 92, 98, 124, 138, 141, 166, 186]
# round!!
# 178
# bot 19 gives low to bot 52 and high to bot 76
# ['', 'high', 'to', 'bot', '76']
# bot 171 gives low to bot 201 and high to bot 23
# ['', 'high', 'to', 'bot', '23']
# bot 13 gives low to bot 31 and high to bot 9
# ['', 'high', 'to', 'bot', '9']
# bot 31 gives low to bot 72 and high to bot 92
# ['', 'high', 'to', 'bot', '92']
# bot 72 gives low to bot 97 and high to bot 150
# ['', 'high', 'to', 'bot', '150']
# bot 9 gives low to bot 92 and high to bot 119
# ['', 'high', 'to', 'bot', '119']
# [62, 99, 110, 117, 140, 169]
# round!!
# 172
# bot 92 gives low to bot 150 and high to bot 131
# ['', 'high', 'to', 'bot', '131']
# bot 52 gives low to bot 143 and high to bot 38
# ['', 'high', 'to', 'bot', '38']
# bot 201 gives low to bot 119 and high to bot 177
# ['', 'high', 'to', 'bot', '177']
# bot 119 gives low to bot 131 and high to bot 169
# ['', 'high', 'to', 'bot', '169']
# bot 131 gives low to bot 99 and high to bot 204
# ['', 'high', 'to', 'bot', '204']
# bot 23 gives low to bot 177 and high to bot 42
# ['', 'high', 'to', 'bot', '42']
# bot 143 gives low to bot 176 and high to bot 88
# ['', 'high', 'to', 'bot', '88']
# bot 97 gives low to bot 207 and high to bot 132
# ['', 'high', 'to', 'bot', '132']
# bot 176 gives low to bot 113 and high to bot 116
# ['', 'high', 'to', 'bot', '116']
# bot 177 gives low to bot 169 and high to bot 22
# ['', 'high', 'to', 'bot', '22']
# bot 207 gives low to bot 76 and high to bot 1
# ['', 'high', 'to', 'bot', '1']
# bot 150 gives low to bot 132 and high to bot 99
# ['', 'high', 'to', 'bot', '99']
# [21, 25, 42, 56, 85, 88, 91, 107, 117, 121, 124, 152]
# round!!
# 160
# bot 99 gives low to bot 41 and high to bot 83
# ['', 'high', 'to', 'bot', '83']
# bot 113 gives low to bot 194 and high to bot 157
# ['', 'high', 'to', 'bot', '157']
# bot 76 gives low to bot 38 and high to bot 155
# ['', 'high', 'to', 'bot', '155']
# bot 169 gives low to bot 204 and high to bot 187
# ['', 'high', 'to', 'bot', '187']
# bot 42 gives low to bot 22 and high to bot 191
# ['', 'high', 'to', 'bot', '191']
# bot 191 gives low to bot 148 and high to bot 12
# ['', 'high', 'to', 'bot', '12']
# bot 132 gives low to bot 1 and high to bot 41
# ['', 'high', 'to', 'bot', '41']
# bot 194 gives low to bot 77 and high to bot 55
# ['', 'high', 'to', 'bot', '55']
# bot 38 gives low to bot 88 and high to bot 43
# ['', 'high', 'to', 'bot', '43']
# [11, 46, 59, 72, 82, 125, 126, 134, 136]
# round!!
# 151
# bot 204 gives low to bot 83 and high to bot 54
# ['', 'high', 'to', 'bot', '54']
# bot 22 gives low to bot 187 and high to bot 148
# ['', 'high', 'to', 'bot', '148']
# bot 187 gives low to bot 54 and high to bot 37
# ['', 'high', 'to', 'bot', '37']
# bot 1 gives low to bot 155 and high to bot 100
# ['', 'high', 'to', 'bot', '100']
# bot 41 gives low to bot 100 and high to bot 18
# ['', 'high', 'to', 'bot', '18']
# bot 148 gives low to bot 37 and high to bot 12
# ['', 'high', 'to', 'bot', '12']
# bot 88 gives low to bot 116 and high to bot 5
# ['', 'high', 'to', 'bot', '5']
# bot 83 gives low to bot 18 and high to bot 29
# ['', 'high', 'to', 'bot', '29']
# bot 77 gives low to output 11 and high to bot 49
# ['', 'high', 'to', 'bot', '49']
# bot 54 gives low to bot 29 and high to bot 44
# ['', 'high', 'to', 'bot', '44']
# bot 100 gives low to bot 78 and high to bot 186
# ['', 'high', 'to', 'bot', '186']
# [13, 14, 18, 30, 83, 87, 100, 101, 123, 131, 145]
# round!!
# 140
# bot 116 gives low to bot 157 and high to bot 197
# ['', 'high', 'to', 'bot', '197']
# bot 18 gives low to bot 186 and high to bot 136
# ['', 'high', 'to', 'bot', '136']
# bot 155 gives low to bot 43 and high to bot 78
# ['', 'high', 'to', 'bot', '78']
# bot 157 gives low to bot 55 and high to bot 185
# ['', 'high', 'to', 'bot', '185']
# bot 37 gives low to bot 44 and high to bot 11
# ['', 'high', 'to', 'bot', '11']
# bot 12 gives low to bot 11 and high to bot 10
# ['', 'high', 'to', 'bot', '10']
# bot 55 gives low to bot 49 and high to bot 57
# ['', 'high', 'to', 'bot', '57']
# bot 186 gives low to bot 33 and high to bot 202
# ['', 'high', 'to', 'bot', '202']
# bot 78 gives low to bot 134 and high to bot 33
# ['', 'high', 'to', 'bot', '33']
# bot 44 gives low to bot 73 and high to bot 63
# ['', 'high', 'to', 'bot', '63']
# bot 11 gives low to bot 63 and high to bot 10
# ['', 'high', 'to', 'bot', '10']
# bot 49 gives low to output 0 and high to bot 118
# ['', 'high', 'to', 'bot', '118']
# bot 43 gives low to bot 5 and high to bot 134
# ['', 'high', 'to', 'bot', '134']
# bot 63 gives low to bot 68 and high to bot 142
# ['', 'high', 'to', 'bot', '142']
# bot 29 gives low to bot 136 and high to bot 73
# ['', 'high', 'to', 'bot', '73']
# bot 73 gives low to bot 47 and high to bot 68
# ['', 'high', 'to', 'bot', '68']
# bot 134 gives low to bot 8 and high to bot 141
# ['', 'high', 'to', 'bot', '141']
# [1, 10, 11, 12, 18, 60, 70, 76, 86, 88, 98, 107, 114, 117, 120, 131, 132]
# round!!
# 123
# bot 33 gives low to bot 141 and high to bot 105
# ['', 'high', 'to', 'bot', '105']
# bot 68 gives low to bot 86 and high to bot 25
# ['', 'high', 'to', 'bot', '25']
# bot 5 gives low to bot 197 and high to bot 8
# ['', 'high', 'to', 'bot', '8']
# bot 136 gives low to bot 202 and high to bot 47
# ['', 'high', 'to', 'bot', '47']
# bot 197 gives low to bot 185 and high to bot 0
# ['', 'high', 'to', 'bot', '0']
# bot 141 gives low to bot 152 and high to bot 175
# THIS IS THE BOT YOU ARE LOOKING FOR141
# ['', 'high', 'to', 'bot', '175']
# bot 8 gives low to bot 0 and high to bot 152
# ['', 'high', 'to', 'bot', '152']
# bot 10 gives low to bot 142 and high to bot 163
# ['', 'high', 'to', 'bot', '163']
# bot 0 gives low to bot 139 and high to bot 30
# ['', 'high', 'to', 'bot', '30']
# bot 152 gives low to bot 30 and high to bot 159
# ['', 'high', 'to', 'bot', '159']
# bot 142 gives low to bot 25 and high to bot 163
# ['', 'high', 'to', 'bot', '163']
# [6, 7, 23, 24, 26, 33, 36, 73, 84, 118, 120]
# round!!
# 112
# bot 185 gives low to bot 57 and high to bot 139
# ['', 'high', 'to', 'bot', '139']
# bot 202 gives low to bot 105 and high to bot 209
# ['', 'high', 'to', 'bot', '209']
# bot 57 gives low to bot 118 and high to bot 32
# ['', 'high', 'to', 'bot', '32']
# bot 139 gives low to bot 32 and high to bot 28
# ['', 'high', 'to', 'bot', '28']
# bot 47 gives low to bot 209 and high to bot 86
# ['', 'high', 'to', 'bot', '86']
# bot 25 gives low to bot 59 and high to bot 71
# ['', 'high', 'to', 'bot', '71']
# bot 118 gives low to output 7 and high to bot 96
# ['', 'high', 'to', 'bot', '96']
# bot 32 gives low to bot 96 and high to bot 90
# ['', 'high', 'to', 'bot', '90']
# bot 86 gives low to bot 172 and high to bot 59
# ['', 'high', 'to', 'bot', '59']
# bot 30 gives low to bot 28 and high to bot 75
# ['', 'high', 'to', 'bot', '75']
# bot 163 gives low to bot 71 and high to bot 14
# ['', 'high', 'to', 'bot', '14']
# bot 71 gives low to bot 130 and high to bot 14
# ['', 'high', 'to', 'bot', '14']
# bot 105 gives low to bot 175 and high to bot 82
# ['', 'high', 'to', 'bot', '82']
# bot 209 gives low to bot 82 and high to bot 172
# ['', 'high', 'to', 'bot', '172']
# bot 28 gives low to bot 90 and high to bot 145
# ['', 'high', 'to', 'bot', '145']
# bot 96 gives low to output 10 and high to bot 66
# ['', 'high', 'to', 'bot', '66']
# [1, 2, 5, 6, 9, 17, 19, 25, 38, 43, 46, 79, 83, 95, 103, 111]
# round!!
# 96
# bot 59 gives low to bot 7 and high to bot 130
# ['', 'high', 'to', 'bot', '130']
# bot 172 gives low to bot 154 and high to bot 7
# ['', 'high', 'to', 'bot', '7']
# bot 14 gives low to bot 153 and high to bot 53
# ['', 'high', 'to', 'bot', '53']
# bot 7 gives low to bot 4 and high to bot 80
# ['', 'high', 'to', 'bot', '80']
# bot 175 gives low to bot 159 and high to bot 67
# ['', 'high', 'to', 'bot', '67']
# bot 159 gives low to bot 75 and high to bot 166
# ['', 'high', 'to', 'bot', '166']
# bot 82 gives low to bot 67 and high to bot 154
# ['', 'high', 'to', 'bot', '154']
# bot 67 gives low to bot 166 and high to bot 138
# ['', 'high', 'to', 'bot', '138']
# bot 130 gives low to bot 80 and high to bot 153
# ['', 'high', 'to', 'bot', '153']
# bot 90 gives low to bot 66 and high to bot 183
# ['', 'high', 'to', 'bot', '183']
# [14, 26, 32, 39, 43, 46, 56, 64, 82, 87]
# round!!
# 86
# bot 75 gives low to bot 145 and high to bot 95
# ['', 'high', 'to', 'bot', '95']
# bot 166 gives low to bot 95 and high to bot 87
# ['', 'high', 'to', 'bot', '87']
# bot 154 gives low to bot 138 and high to bot 4
# ['', 'high', 'to', 'bot', '4']
# bot 80 gives low to bot 17 and high to bot 84
# ['', 'high', 'to', 'bot', '84']
# bot 138 gives low to bot 87 and high to bot 65
# ['', 'high', 'to', 'bot', '65']
# bot 145 gives low to bot 183 and high to bot 146
# ['', 'high', 'to', 'bot', '146']
# bot 183 gives low to bot 190 and high to bot 174
# ['', 'high', 'to', 'bot', '174']
# bot 95 gives low to bot 146 and high to bot 94
# ['', 'high', 'to', 'bot', '94']
# bot 87 gives low to bot 94 and high to bot 147
# ['', 'high', 'to', 'bot', '147']
# bot 66 gives low to output 4 and high to bot 190
# ['', 'high', 'to', 'bot', '190']
# bot 4 gives low to bot 65 and high to bot 17
# ['', 'high', 'to', 'bot', '17']
# bot 153 gives low to bot 84 and high to bot 53
# ['', 'high', 'to', 'bot', '53']
# bot 53 gives low to bot 21 and high to bot 135
# ['', 'high', 'to', 'bot', '135']
# [0, 2, 3, 7, 15, 19, 39, 40, 46, 48, 59, 63, 78]
# round!!
# 73
# bot 17 gives low to bot 93 and high to bot 109
# ['', 'high', 'to', 'bot', '109']
# bot 94 gives low to bot 16 and high to bot 39
# ['', 'high', 'to', 'bot', '39']
# bot 190 gives low to output 1 and high to bot 36
# ['', 'high', 'to', 'bot', '36']
# bot 65 gives low to bot 147 and high to bot 93
# ['', 'high', 'to', 'bot', '93']
# bot 84 gives low to bot 109 and high to bot 21
# ['', 'high', 'to', 'bot', '21']
# bot 109 gives low to bot 121 and high to bot 102
# ['', 'high', 'to', 'bot', '102']
# bot 146 gives low to bot 174 and high to bot 16
# ['', 'high', 'to', 'bot', '16']
# bot 16 gives low to bot 124 and high to bot 85
# ['', 'high', 'to', 'bot', '85']
# bot 21 gives low to bot 102 and high to bot 135
# ['', 'high', 'to', 'bot', '135']
# bot 147 gives low to bot 39 and high to bot 184
# ['', 'high', 'to', 'bot', '184']
# bot 93 gives low to bot 184 and high to bot 121
# ['', 'high', 'to', 'bot', '121']
# [6, 10, 14, 16, 21, 22, 27, 58, 60, 64, 65]
# round!!
# 62
# bot 102 gives low to bot 56 and high to bot 164
# ['', 'high', 'to', 'bot', '164']
# bot 174 gives low to bot 36 and high to bot 124
# ['', 'high', 'to', 'bot', '124']
# bot 121 gives low to bot 60 and high to bot 56
# ['', 'high', 'to', 'bot', '56']
# bot 36 gives low to output 6 and high to bot 26
# ['', 'high', 'to', 'bot', '26']
# bot 39 gives low to bot 85 and high to bot 89
# ['', 'high', 'to', 'bot', '89']
# bot 184 gives low to bot 89 and high to bot 60
# ['', 'high', 'to', 'bot', '60']
# bot 89 gives low to bot 108 and high to bot 158
# ['', 'high', 'to', 'bot', '158']
# bot 135 gives low to bot 164 and high to bot 40
# ['', 'high', 'to', 'bot', '40']
# bot 164 gives low to bot 6 and high to bot 40
# ['', 'high', 'to', 'bot', '40']
# bot 124 gives low to bot 26 and high to bot 98
# ['', 'high', 'to', 'bot', '98']
# bot 56 gives low to bot 34 and high to bot 6
# ['', 'high', 'to', 'bot', '6']
# [3, 10, 19, 32, 34, 39, 40, 44, 45, 46, 53]
# round!!
# 51
# bot 60 gives low to bot 158 and high to bot 34
# ['', 'high', 'to', 'bot', '34']
# bot 6 gives low to bot 205 and high to bot 182
# ['', 'high', 'to', 'bot', '182']
# bot 85 gives low to bot 98 and high to bot 108
# ['', 'high', 'to', 'bot', '108']
# bot 40 gives low to bot 182 and high to bot 70
# ['', 'high', 'to', 'bot', '70']
# bot 158 gives low to bot 101 and high to bot 178
# ['', 'high', 'to', 'bot', '178']
# bot 182 gives low to bot 50 and high to bot 70
# ['', 'high', 'to', 'bot', '70']
# bot 26 gives low to output 19 and high to bot 111
# ['', 'high', 'to', 'bot', '111']
# bot 108 gives low to bot 46 and high to bot 101
# ['', 'high', 'to', 'bot', '101']
# bot 34 gives low to bot 178 and high to bot 205
# ['', 'high', 'to', 'bot', '205']
# [9, 11, 20, 21, 22, 33, 34, 35, 48]
# round!!
# 42
# bot 98 gives low to bot 111 and high to bot 46
# ['', 'high', 'to', 'bot', '46']
# bot 101 gives low to bot 64 and high to bot 173
# ['', 'high', 'to', 'bot', '173']
# bot 70 gives low to bot 199 and high to bot 156
# ['', 'high', 'to', 'bot', '156']
# bot 205 gives low to bot 127 and high to bot 50
# ['', 'high', 'to', 'bot', '50']
# bot 50 gives low to bot 129 and high to bot 199
# ['', 'high', 'to', 'bot', '199']
# bot 46 gives low to bot 103 and high to bot 64
# ['', 'high', 'to', 'bot', '64']
# bot 111 gives low to output 18 and high to bot 103
# ['', 'high', 'to', 'bot', '103']
# bot 178 gives low to bot 173 and high to bot 127
# ['', 'high', 'to', 'bot', '127']
# [10, 17, 19, 22, 23, 26, 31, 34]
# round!!
# 34
# bot 103 gives low to output 13 and high to bot 125
# ['', 'high', 'to', 'bot', '125']
# bot 173 gives low to bot 192 and high to bot 126
# ['', 'high', 'to', 'bot', '126']
# bot 64 gives low to bot 125 and high to bot 192
# ['', 'high', 'to', 'bot', '192']
# bot 199 gives low to bot 117 and high to bot 156
# ['', 'high', 'to', 'bot', '156']
# bot 125 gives low to output 2 and high to bot 107
# ['', 'high', 'to', 'bot', '107']
# bot 127 gives low to bot 126 and high to bot 129
# ['', 'high', 'to', 'bot', '129']
# bot 126 gives low to bot 188 and high to bot 149
# ['', 'high', 'to', 'bot', '149']
# bot 192 gives low to bot 107 and high to bot 188
# ['', 'high', 'to', 'bot', '188']
# bot 156 gives low to bot 168 and high to bot 2
# ['', 'high', 'to', 'bot', '2']
# bot 129 gives low to bot 149 and high to bot 117
# ['', 'high', 'to', 'bot', '117']
# bot 149 gives low to bot 180 and high to bot 81
# ['', 'high', 'to', 'bot', '81']
# [2, 6, 7, 10, 12, 15, 22, 25, 26, 31, 32]
# round!!
# 23
# bot 188 gives low to bot 161 and high to bot 180
# ['', 'high', 'to', 'bot', '180']
# bot 117 gives low to bot 81 and high to bot 168
# ['', 'high', 'to', 'bot', '168']
# bot 180 gives low to bot 106 and high to bot 15
# ['', 'high', 'to', 'bot', '15']
# bot 107 gives low to output 9 and high to bot 161
# ['', 'high', 'to', 'bot', '161']
# bot 81 gives low to bot 15 and high to bot 170
# ['', 'high', 'to', 'bot', '170']
# bot 161 gives low to output 3 and high to bot 106
# ['', 'high', 'to', 'bot', '106']
# bot 15 gives low to bot 200 and high to bot 193
# ['', 'high', 'to', 'bot', '193']
# [3, 4, 8, 11, 12, 21, 22]
# round!!
# 16
# bot 168 gives low to bot 170 and high to bot 2
# ['', 'high', 'to', 'bot', '2']
# bot 170 gives low to bot 193 and high to bot 91
# ['', 'high', 'to', 'bot', '91']
# bot 193 gives low to bot 206 and high to bot 167
# ['', 'high', 'to', 'bot', '167']
# bot 106 gives low to output 12 and high to bot 200
# ['', 'high', 'to', 'bot', '200']
# bot 2 gives low to bot 91 and high to bot 20
# ['', 'high', 'to', 'bot', '20']
# bot 91 gives low to bot 167 and high to bot 20
# ['', 'high', 'to', 'bot', '20']
# [2, 4, 11, 13, 14, 15]
# round!!
# 10
# bot 20 gives low to bot 128 and high to bot 208
# ['', 'high', 'to', 'bot', '208']
# bot 200 gives low to output 16 and high to bot 206
# ['', 'high', 'to', 'bot', '206']
# bot 167 gives low to bot 203 and high to bot 128
# ['', 'high', 'to', 'bot', '128']
# [2, 4, 7]
# round!!
# 7
# bot 206 gives low to output 15 and high to bot 203
# ['', 'high', 'to', 'bot', '203']
# bot 128 gives low to bot 179 and high to bot 208
# ['', 'high', 'to', 'bot', '208']
# bot 208 gives low to bot 133 and high to bot 196
# ['', 'high', 'to', 'bot', '196']
# bot 203 gives low to output 14 and high to bot 179
# ['', 'high', 'to', 'bot', '179']
# [1, 2, 3, 5]
# round!!
# 3
# bot 179 gives low to output 20 and high to bot 133
# ['', 'high', 'to', 'bot', '133']
# bot 133 gives low to output 5 and high to bot 196
# ['', 'high', 'to', 'bot', '196']
# [0, 2]
# ['bot 196 gives low to output 17 and high to output 8']
# BOTS
# 133 set([-1])
# 132 set([-1])
# 131 set([-1])
# 130 set([-1])
# 137 set([-1])
# 136 set([-1])
# 135 set([-1])
# 134 set([-1])
# 139 set([-1])
# 138 set([-1])
# 93 set([-1])
# 24 set([-1])
# 25 set([-1])
# 86 set([-1])
# 27 set([-1])
# 20 set([-1])
# 21 set([-1])
# 22 set([-1])
# 23 set([-1])
# 95 set([-1])
# 28 set([-1])
# 29 set([-1])
# 161 set([-1])
# 0 set([-1])
# 162 set([-1])
# 8 set([-1])
# 96 set([-1])
# 68 set([-1])
# 87 set([-1])
# 120 set([-1])
# 121 set([-1])
# 122 set([-1])
# 123 set([-1])
# 124 set([-1])
# 125 set([-1])
# 126 set([-1])
# 127 set([-1])
# 128 set([-1])
# 129 set([-1])
# 69 set([-1])
# 91 set([-1])
# 59 set([-1])
# 58 set([-1])
# 55 set([-1])
# 54 set([-1])
# 57 set([-1])
# 56 set([-1])
# 51 set([-1])
# 50 set([-1])
# 53 set([-1])
# 52 set([-1])
# 90 set([-1])
# 146 set([-1])
# 199 set([-1])
# 198 set([-1])
# 200 set([-1])
# 195 set([-1])
# 194 set([-1])
# 197 set([-1])
# 178 set([-1])
# 191 set([-1])
# 190 set([-1])
# 193 set([-1])
# 192 set([-1])
# 115 set([-1])
# 114 set([-1])
# 88 set([-1])
# 116 set([-1])
# 111 set([-1])
# 110 set([-1])
# 113 set([-1])
# 112 set([-1])
# 82 set([-1])
# 83 set([-1])
# 80 set([-1])
# 81 set([-1])
# 119 set([-1])
# 118 set([-1])
# 84 set([-1])
# 143 set([-1])
# 140 set([-1])
# 206 set([-1])
# 3 set([-1])
# 7 set([-1])
# 26 set([-1])
# 108 set([-1])
# 109 set([-1])
# 102 set([-1])
# 103 set([-1])
# 100 set([-1])
# 101 set([-1])
# 106 set([-1])
# 107 set([-1])
# 104 set([-1])
# 105 set([-1])
# 39 set([-1])
# 38 set([-1])
# 33 set([-1])
# 32 set([-1])
# 31 set([-1])
# 30 set([-1])
# 37 set([-1])
# 36 set([-1])
# 35 set([-1])
# 34 set([-1])
# 205 set([-1])
# 60 set([-1])
# 61 set([-1])
# 62 set([-1])
# 63 set([-1])
# 64 set([-1])
# 65 set([-1])
# 66 set([-1])
# 67 set([-1])
# 177 set([-1])
# 176 set([-1])
# 175 set([-1])
# 174 set([-1])
# 173 set([-1])
# 172 set([-1])
# 171 set([-1])
# 170 set([-1])
# 203 set([-1])
# 145 set([-1])
# 182 set([-1])
# 183 set([-1])
# 180 set([-1])
# 181 set([-1])
# 186 set([-1])
# 187 set([-1])
# 184 set([-1])
# 185 set([-1])
# 188 set([-1])
# 189 set([-1])
# 4 set([-1])
# 179 set([-1])
# 196 (73, 71)
# 6 set([-1])
# 99 set([-1])
# 98 set([-1])
# 168 set([-1])
# 169 set([-1])
# 164 set([-1])
# 165 set([-1])
# 166 set([-1])
# 92 set([-1])
# 160 set([-1])
# 94 set([-1])
# 97 set([-1])
# 163 set([-1])
# 11 set([-1])
# 10 set([-1])
# 13 set([-1])
# 12 set([-1])
# 15 set([-1])
# 14 set([-1])
# 17 set([-1])
# 16 set([-1])
# 19 set([-1])
# 18 set([-1])
# 117 set([-1])
# 89 set([-1])
# 151 set([-1])
# 150 set([-1])
# 153 set([-1])
# 152 set([-1])
# 155 set([-1])
# 154 set([-1])
# 157 set([-1])
# 156 set([-1])
# 159 set([-1])
# 158 set([-1])
# 48 set([-1])
# 49 set([-1])
# 46 set([-1])
# 47 set([-1])
# 44 set([-1])
# 45 set([-1])
# 42 set([-1])
# 43 set([-1])
# 40 set([-1])
# 41 set([-1])
# 1 set([-1])
# 5 set([-1])
# 9 set([-1])
# 85 set([-1])
# 201 set([-1])
# 147 set([-1])
# 144 set([-1])
# 202 set([-1])
# 142 set([-1])
# 204 set([-1])
# 207 set([-1])
# 141 set([-1])
# 209 set([-1])
# 208 set([-1])
# 148 set([-1])
# 149 set([-1])
# 77 set([-1])
# 76 set([-1])
# 75 set([-1])
# 74 set([-1])
# 73 set([-1])
# 72 set([-1])
# 71 set([-1])
# 70 set([-1])
# 79 set([-1])
# 78 set([-1])
# 2 set([-1])
# 167 set([-1])

# %%
def decompress(line):
    decompressed_output = ""
    split_line = line.replace(')','(')
    split_line = split_line.split('(')
    for idx in range(len(split_line)):
        
        ## check if this is a marker
        if 'x' in split_line[idx]:
            marker = split_line[idx]
            count = int(marker.split('x')[0])
            times = int(marker.split('x')[1])
            
            ## assemble the subsequent characters
            ass_idx = idx+1
            assembeled = ""
            current_count = count
            while len(assembeled) < count:
                if 'x' in split_line[ass_idx]:
                    split_line[ass_idx] = '(' + split_line[ass_idx] + ')'
                grab_amount = min(len(split_line[ass_idx]),current_count)
                assembeled += split_line[ass_idx][0:grab_amount]
                split_line[ass_idx] = split_line[ass_idx][grab_amount:]
                ass_idx += 1
                current_count -= grab_amount
                
            for repeat in range(times):
                decompressed_output += assembeled
        else:
            decompressed_output += split_line[idx]
    return decompressed_output

# %%
def decompress2(line):
    decompressed = ""
    idx = 0
    while idx < len(line):
        ## start of marker
        if line[idx] == "(":
            pre_marker_idx = idx
            idx+=1 
            marker = ""
            while line[idx] != ")":
                marker += line[idx]
                idx+=1 
            idx+=1
            count = int(marker.split('x')[0])
            times = int(marker.split('x')[1])
            expanded = ""
            for expanded_idx in range(times):
                expanded += line[idx:idx+count]
            post_marker_idx = idx + count
            decompressed = decompressed + expanded
            idx += count
        else:
            decompressed += line[idx]
            idx+=1
    return decompressed

# %%
def decompress3(line):
    if "x" not in line:
        return line
    decompressed = ""
    idx = 0
    while idx < len(line):
        ## start of marker
        if line[idx] == "(":
            idx+=1 
            marker = ""
            while line[idx] != ")":
                marker += line[idx]
                idx+=1 
            idx+=1
            count = int(marker.split('x')[0])
            times = int(marker.split('x')[1])
            expanded = ""
            for expanded_idx in range(times):
                expanded += line[idx:idx+count]
            ## continue to decompress the output
            while "x" in expanded:
                expanded = decompress3(expanded)
            decompressed = decompressed + expanded
            idx += count
        else:
            decompressed += line[idx]
            idx+=1
    return decompressed


data = pd.read_csv('./input.txt',header=None,delim_whitespace=False)

decompressed_output = ""

for line in data[0]:
    decompressed_output += decompress3(line)
print "decompressed: " + str(len(decompressed_output))
#stop = False
#while '(' in decompressed_output:
#    print decompressed_output[0:250]
#    print "markers: " + str(decompressed_output.count('x'))
#    decompressed_output = decompress(decompressed_output)
#    print len(decompressed_output)
#    
#print "super decompressed: " + str(len(decompressed_output))
# Out:
# decompressed: 10780403063

# %%
# data = pd.read_csv('./input.txt',header=None,delim_whitespace=False)
rows = 6
cols = 50
screen = np.zeros((rows,cols))
#print screen

for line in data[0]:
    instructions = line.split()
    # turn on from top left
    if(instructions[0] == "rect"):
        cols = int(instructions[1].split("x")[0])
        rows = int(instructions[1].split("x")[1])
        screen[0:rows,0:cols] = np.ones((rows,cols))
    elif(instructions[0] == "rotate"):
        dimension = instructions[1]
        idx = int(instructions[2].split("=")[1])
        amount = int(instructions[4])
        if dimension == "column":
            ## extract the column
            column = screen[:,idx].copy()
            for col_idx in range(len(column)):
                screen_idx = (col_idx+amount) % (screen.shape[0])
                screen[screen_idx,idx] = column[col_idx]
        elif dimension == "row":
            ## extract the row
            row = screen[idx,:].copy()
            for row_idx in range(len(row)):
                screen_idx = (row_idx+amount) % (screen.shape[1])
                screen[idx,screen_idx] = row[row_idx]

print np.count_nonzero(screen)


print screen.shape
screen_range = screen.shape[1]/5
for i in range(screen_range):
    print type
    letter = screen[:,i*5:i*5+5]
    for row in range(letter.shape[0]):
        message = ""
        for col in range(letter.shape[1]):
            if(letter[row,col] == 0):
                message += "."
            else:
                message += "#"
        print message
