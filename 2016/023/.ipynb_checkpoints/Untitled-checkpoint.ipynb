# %%
import pandas as pd
import numpy as np
import math
import collections
import re
import sys
import itertools

# %%
def is_digit(num):
    try:
        int(num)
        is_digit=True
    except ValueError:
        is_digit=False
        
    return is_digit

# %%
def cpy(cmd,registers):
    value = 0
    if cmd[2] not in registers:
        return
    
    if is_digit(cmd[1]):
        value = int(cmd[1])
    else:
        value = registers[cmd[1]]
    registers[cmd[2]] = value  
    
def sum(cmd,registers):
    if is_digit(cmd[1]):
        value = int(cmd[1])
    else:
        value = registers[cmd[1]]
    registers[cmd[2]] += value
    
def mul(cmd,registers):
    if is_digit(cmd[1]):
        value = int(cmd[1])
    else:
        value = registers[cmd[1]]
    registers[cmd[2]] *= value
    
def jnz(cmd,registers):
    if is_digit(cmd[1]):
        check = int(cmd[1])
    else:
        check = registers[cmd[1]]
        
    if check != 0:
        if is_digit(cmd[2]):
            return int(cmd[2])
        else:
            return registers[cmd[2]]
        
    return 0

def tgl(cmd,idx,commands,registers):
    location = 0
    if cmd[1].isdigit():
        location = idx+int(cmd[1])
    else:
        location = idx+registers[cmd[1]]
    
    if location > len(commands)-1:
        return
    
    tglcmd = commands[location]
    
    if len(tglcmd) == 2:
        if tglcmd[0] == 'inc':
            tglcmd[0] = 'dec'
        else:
            tglcmd[0] = 'inc'
    else:
        if tglcmd[0] == 'jnz':
            tglcmd[0] = 'cpy'
        else:
            tglcmd[0] = 'jnz'
            
    commands[location] = tglcmd

# %%
data = pd.read_csv('./input.txt',header=None,delim_whitespace=False)
lines = data.values
registers = {}
registers['a'] = 12
registers['b'] = 0
registers['c'] = 0
registers['d'] = 0
commands = [line[0].split(' ') for line in lines]
idx2 = 0
idx = 0
while idx < len(commands) and idx2 < 500:
    if idx >= len(commands):
        break
    cmd = commands[idx]
    
    print idx
    print cmd
    jump = 0
    if cmd[0] == 'cpy':
        cpy(cmd,registers)
    elif cmd[0] == 'sum':
        sum(cmd,registers)
    elif cmd[0] == 'mul':
        mul(cmd,registers)
    elif cmd[0] == 'inc':
        if cmd[1] in registers:
            registers[cmd[1]] += 1
    elif cmd[0] == 'dec':
        if cmd[1] in registers:
            registers[cmd[1]] -= 1
    elif cmd[0] == 'jnz':
        jump = jnz(cmd,registers)
    elif cmd[0] == 'tgl':
        tgl(cmd,idx,commands,registers)
    if jump == 0:
        idx += 1 
    else:
        idx += jump
    idx2 += 1  
    print registers   
print registers
# Out:
# 0
# ['cpy', 'a', 'b']
# {'a': 12, 'c': 0, 'b': 12, 'd': 0}
# 1
# ['dec', 'b']
# {'a': 12, 'c': 0, 'b': 11, 'd': 0}
# 2
# ['cpy', 'a', 'd']
# {'a': 12, 'c': 0, 'b': 11, 'd': 12}
# 3
# ['cpy', '0', 'a']
# {'a': 0, 'c': 0, 'b': 11, 'd': 12}
# 4
# ['cpy', 'b', 'c']
# {'a': 0, 'c': 11, 'b': 11, 'd': 12}
# 5
# ['sum', 'c', 'a']
# {'a': 11, 'c': 11, 'b': 11, 'd': 12}
# 6
# ['cpy', '0', 'c']
# {'a': 11, 'c': 0, 'b': 11, 'd': 12}
# 7
# ['jnz', 'c', '-2']
# {'a': 11, 'c': 0, 'b': 11, 'd': 12}
# 8
# ['dec', 'd']
# {'a': 11, 'c': 0, 'b': 11, 'd': 11}
# 9
# ['jnz', 'd', '-5']
# {'a': 11, 'c': 0, 'b': 11, 'd': 11}
# 4
# ['cpy', 'b', 'c']
# {'a': 11, 'c': 11, 'b': 11, 'd': 11}
# 5
# ['sum', 'c', 'a']
# {'a': 22, 'c': 11, 'b': 11, 'd': 11}
# 6
# ['cpy', '0', 'c']
# {'a': 22, 'c': 0, 'b': 11, 'd': 11}
# 7
# ['jnz', 'c', '-2']
# {'a': 22, 'c': 0, 'b': 11, 'd': 11}
# 8
# ['dec', 'd']
# {'a': 22, 'c': 0, 'b': 11, 'd': 10}
# 9
# ['jnz', 'd', '-5']
# {'a': 22, 'c': 0, 'b': 11, 'd': 10}
# 4
# ['cpy', 'b', 'c']
# {'a': 22, 'c': 11, 'b': 11, 'd': 10}
# 5
# ['sum', 'c', 'a']
# {'a': 33, 'c': 11, 'b': 11, 'd': 10}
# 6
# ['cpy', '0', 'c']
# {'a': 33, 'c': 0, 'b': 11, 'd': 10}
# 7
# ['jnz', 'c', '-2']
# {'a': 33, 'c': 0, 'b': 11, 'd': 10}
# 8
# ['dec', 'd']
# {'a': 33, 'c': 0, 'b': 11, 'd': 9}
# 9
# ['jnz', 'd', '-5']
# {'a': 33, 'c': 0, 'b': 11, 'd': 9}
# 4
# ['cpy', 'b', 'c']
# {'a': 33, 'c': 11, 'b': 11, 'd': 9}
# 5
# ['sum', 'c', 'a']
# {'a': 44, 'c': 11, 'b': 11, 'd': 9}
# 6
# ['cpy', '0', 'c']
# {'a': 44, 'c': 0, 'b': 11, 'd': 9}
# 7
# ['jnz', 'c', '-2']
# {'a': 44, 'c': 0, 'b': 11, 'd': 9}
# 8
# ['dec', 'd']
# {'a': 44, 'c': 0, 'b': 11, 'd': 8}
# 9
# ['jnz', 'd', '-5']
# {'a': 44, 'c': 0, 'b': 11, 'd': 8}
# 4
# ['cpy', 'b', 'c']
# {'a': 44, 'c': 11, 'b': 11, 'd': 8}
# 5
# ['sum', 'c', 'a']
# {'a': 55, 'c': 11, 'b': 11, 'd': 8}
# 6
# ['cpy', '0', 'c']
# {'a': 55, 'c': 0, 'b': 11, 'd': 8}
# 7
# ['jnz', 'c', '-2']
# {'a': 55, 'c': 0, 'b': 11, 'd': 8}
# 8
# ['dec', 'd']
# {'a': 55, 'c': 0, 'b': 11, 'd': 7}
# 9
# ['jnz', 'd', '-5']
# {'a': 55, 'c': 0, 'b': 11, 'd': 7}
# 4
# ['cpy', 'b', 'c']
# {'a': 55, 'c': 11, 'b': 11, 'd': 7}
# 5
# ['sum', 'c', 'a']
# {'a': 66, 'c': 11, 'b': 11, 'd': 7}
# 6
# ['cpy', '0', 'c']
# {'a': 66, 'c': 0, 'b': 11, 'd': 7}
# 7
# ['jnz', 'c', '-2']
# {'a': 66, 'c': 0, 'b': 11, 'd': 7}
# 8
# ['dec', 'd']
# {'a': 66, 'c': 0, 'b': 11, 'd': 6}
# 9
# ['jnz', 'd', '-5']
# {'a': 66, 'c': 0, 'b': 11, 'd': 6}
# 4
# ['cpy', 'b', 'c']
# {'a': 66, 'c': 11, 'b': 11, 'd': 6}
# 5
# ['sum', 'c', 'a']
# {'a': 77, 'c': 11, 'b': 11, 'd': 6}
# 6
# ['cpy', '0', 'c']
# {'a': 77, 'c': 0, 'b': 11, 'd': 6}
# 7
# ['jnz', 'c', '-2']
# {'a': 77, 'c': 0, 'b': 11, 'd': 6}
# 8
# ['dec', 'd']
# {'a': 77, 'c': 0, 'b': 11, 'd': 5}
# 9
# ['jnz', 'd', '-5']
# {'a': 77, 'c': 0, 'b': 11, 'd': 5}
# 4
# ['cpy', 'b', 'c']
# {'a': 77, 'c': 11, 'b': 11, 'd': 5}
# 5
# ['sum', 'c', 'a']
# {'a': 88, 'c': 11, 'b': 11, 'd': 5}
# 6
# ['cpy', '0', 'c']
# {'a': 88, 'c': 0, 'b': 11, 'd': 5}
# 7
# ['jnz', 'c', '-2']
# {'a': 88, 'c': 0, 'b': 11, 'd': 5}
# 8
# ['dec', 'd']
# {'a': 88, 'c': 0, 'b': 11, 'd': 4}
# 9
# ['jnz', 'd', '-5']
# {'a': 88, 'c': 0, 'b': 11, 'd': 4}
# 4
# ['cpy', 'b', 'c']
# {'a': 88, 'c': 11, 'b': 11, 'd': 4}
# 5
# ['sum', 'c', 'a']
# {'a': 99, 'c': 11, 'b': 11, 'd': 4}
# 6
# ['cpy', '0', 'c']
# {'a': 99, 'c': 0, 'b': 11, 'd': 4}
# 7
# ['jnz', 'c', '-2']
# {'a': 99, 'c': 0, 'b': 11, 'd': 4}
# 8
# ['dec', 'd']
# {'a': 99, 'c': 0, 'b': 11, 'd': 3}
# 9
# ['jnz', 'd', '-5']
# {'a': 99, 'c': 0, 'b': 11, 'd': 3}
# 4
# ['cpy', 'b', 'c']
# {'a': 99, 'c': 11, 'b': 11, 'd': 3}
# 5
# ['sum', 'c', 'a']
# {'a': 110, 'c': 11, 'b': 11, 'd': 3}
# 6
# ['cpy', '0', 'c']
# {'a': 110, 'c': 0, 'b': 11, 'd': 3}
# 7
# ['jnz', 'c', '-2']
# {'a': 110, 'c': 0, 'b': 11, 'd': 3}
# 8
# ['dec', 'd']
# {'a': 110, 'c': 0, 'b': 11, 'd': 2}
# 9
# ['jnz', 'd', '-5']
# {'a': 110, 'c': 0, 'b': 11, 'd': 2}
# 4
# ['cpy', 'b', 'c']
# {'a': 110, 'c': 11, 'b': 11, 'd': 2}
# 5
# ['sum', 'c', 'a']
# {'a': 121, 'c': 11, 'b': 11, 'd': 2}
# 6
# ['cpy', '0', 'c']
# {'a': 121, 'c': 0, 'b': 11, 'd': 2}
# 7
# ['jnz', 'c', '-2']
# {'a': 121, 'c': 0, 'b': 11, 'd': 2}
# 8
# ['dec', 'd']
# {'a': 121, 'c': 0, 'b': 11, 'd': 1}
# 9
# ['jnz', 'd', '-5']
# {'a': 121, 'c': 0, 'b': 11, 'd': 1}
# 4
# ['cpy', 'b', 'c']
# {'a': 121, 'c': 11, 'b': 11, 'd': 1}
# 5
# ['sum', 'c', 'a']
# {'a': 132, 'c': 11, 'b': 11, 'd': 1}
# 6
# ['cpy', '0', 'c']
# {'a': 132, 'c': 0, 'b': 11, 'd': 1}
# 7
# ['jnz', 'c', '-2']
# {'a': 132, 'c': 0, 'b': 11, 'd': 1}
# 8
# ['dec', 'd']
# {'a': 132, 'c': 0, 'b': 11, 'd': 0}
# 9
# ['jnz', 'd', '-5']
# {'a': 132, 'c': 0, 'b': 11, 'd': 0}
# 10
# ['dec', 'b']
# {'a': 132, 'c': 0, 'b': 10, 'd': 0}
# 11
# ['cpy', 'b', 'c']
# {'a': 132, 'c': 10, 'b': 10, 'd': 0}
# 12
# ['cpy', 'c', 'd']
# {'a': 132, 'c': 10, 'b': 10, 'd': 10}
# 13
# ['sum', 'd', 'c']
# {'a': 132, 'c': 20, 'b': 10, 'd': 10}
# 14
# ['cpy', '0', 'd']
# {'a': 132, 'c': 20, 'b': 10, 'd': 0}
# 15
# ['jnz', 'd', '-2']
# {'a': 132, 'c': 20, 'b': 10, 'd': 0}
# 16
# ['tgl', 'c']
# {'a': 132, 'c': 20, 'b': 10, 'd': 0}
# 17
# ['cpy', '-16', 'c']
# {'a': 132, 'c': -16, 'b': 10, 'd': 0}
# 18
# ['jnz', '1', 'c']
# {'a': 132, 'c': -16, 'b': 10, 'd': 0}
# 2
# ['cpy', 'a', 'd']
# {'a': 132, 'c': -16, 'b': 10, 'd': 132}
# 3
# ['cpy', '0', 'a']
# {'a': 0, 'c': -16, 'b': 10, 'd': 132}
# 4
# ['cpy', 'b', 'c']
# {'a': 0, 'c': 10, 'b': 10, 'd': 132}
# 5
# ['sum', 'c', 'a']
# {'a': 10, 'c': 10, 'b': 10, 'd': 132}
# 6
# ['cpy', '0', 'c']
# {'a': 10, 'c': 0, 'b': 10, 'd': 132}
# 7
# ['jnz', 'c', '-2']
# {'a': 10, 'c': 0, 'b': 10, 'd': 132}
# 8
# ['dec', 'd']
# {'a': 10, 'c': 0, 'b': 10, 'd': 131}
# 9
# ['jnz', 'd', '-5']
# {'a': 10, 'c': 0, 'b': 10, 'd': 131}
# 4
# ['cpy', 'b', 'c']
# {'a': 10, 'c': 10, 'b': 10, 'd': 131}
# 5
# ['sum', 'c', 'a']
# {'a': 20, 'c': 10, 'b': 10, 'd': 131}
# 6
# ['cpy', '0', 'c']
# {'a': 20, 'c': 0, 'b': 10, 'd': 131}
# 7
# ['jnz', 'c', '-2']
# {'a': 20, 'c': 0, 'b': 10, 'd': 131}
# 8
# ['dec', 'd']
# {'a': 20, 'c': 0, 'b': 10, 'd': 130}
# 9
# ['jnz', 'd', '-5']
# {'a': 20, 'c': 0, 'b': 10, 'd': 130}
# 4
# ['cpy', 'b', 'c']
# {'a': 20, 'c': 10, 'b': 10, 'd': 130}
# 5
# ['sum', 'c', 'a']
# {'a': 30, 'c': 10, 'b': 10, 'd': 130}
# 6
# ['cpy', '0', 'c']
# {'a': 30, 'c': 0, 'b': 10, 'd': 130}
# 7
# ['jnz', 'c', '-2']
# {'a': 30, 'c': 0, 'b': 10, 'd': 130}
# 8
# ['dec', 'd']
# {'a': 30, 'c': 0, 'b': 10, 'd': 129}
# 9
# ['jnz', 'd', '-5']
# {'a': 30, 'c': 0, 'b': 10, 'd': 129}
# 4
# ['cpy', 'b', 'c']
# {'a': 30, 'c': 10, 'b': 10, 'd': 129}
# 5
# ['sum', 'c', 'a']
# {'a': 40, 'c': 10, 'b': 10, 'd': 129}
# 6
# ['cpy', '0', 'c']
# {'a': 40, 'c': 0, 'b': 10, 'd': 129}
# 7
# ['jnz', 'c', '-2']
# {'a': 40, 'c': 0, 'b': 10, 'd': 129}
# 8
# ['dec', 'd']
# {'a': 40, 'c': 0, 'b': 10, 'd': 128}
# 9
# ['jnz', 'd', '-5']
# {'a': 40, 'c': 0, 'b': 10, 'd': 128}
# 4
# ['cpy', 'b', 'c']
# {'a': 40, 'c': 10, 'b': 10, 'd': 128}
# 5
# ['sum', 'c', 'a']
# {'a': 50, 'c': 10, 'b': 10, 'd': 128}
# 6
# ['cpy', '0', 'c']
# {'a': 50, 'c': 0, 'b': 10, 'd': 128}
# 7
# ['jnz', 'c', '-2']
# {'a': 50, 'c': 0, 'b': 10, 'd': 128}
# 8
# ['dec', 'd']
# {'a': 50, 'c': 0, 'b': 10, 'd': 127}
# 9
# ['jnz', 'd', '-5']
# {'a': 50, 'c': 0, 'b': 10, 'd': 127}
# 4
# ['cpy', 'b', 'c']
# {'a': 50, 'c': 10, 'b': 10, 'd': 127}
# 5
# ['sum', 'c', 'a']
# {'a': 60, 'c': 10, 'b': 10, 'd': 127}
# 6
# ['cpy', '0', 'c']
# {'a': 60, 'c': 0, 'b': 10, 'd': 127}
# 7
# ['jnz', 'c', '-2']
# {'a': 60, 'c': 0, 'b': 10, 'd': 127}
# 8
# ['dec', 'd']
# {'a': 60, 'c': 0, 'b': 10, 'd': 126}
# 9
# ['jnz', 'd', '-5']
# {'a': 60, 'c': 0, 'b': 10, 'd': 126}
# 4
# ['cpy', 'b', 'c']
# {'a': 60, 'c': 10, 'b': 10, 'd': 126}
# 5
# ['sum', 'c', 'a']
# {'a': 70, 'c': 10, 'b': 10, 'd': 126}
# 6
# ['cpy', '0', 'c']
# {'a': 70, 'c': 0, 'b': 10, 'd': 126}
# 7
# ['jnz', 'c', '-2']
# {'a': 70, 'c': 0, 'b': 10, 'd': 126}
# 8
# ['dec', 'd']
# {'a': 70, 'c': 0, 'b': 10, 'd': 125}
# 9
# ['jnz', 'd', '-5']
# {'a': 70, 'c': 0, 'b': 10, 'd': 125}
# 4
# ['cpy', 'b', 'c']
# {'a': 70, 'c': 10, 'b': 10, 'd': 125}
# 5
# ['sum', 'c', 'a']
# {'a': 80, 'c': 10, 'b': 10, 'd': 125}
# 6
# ['cpy', '0', 'c']
# {'a': 80, 'c': 0, 'b': 10, 'd': 125}
# 7
# ['jnz', 'c', '-2']
# {'a': 80, 'c': 0, 'b': 10, 'd': 125}
# 8
# ['dec', 'd']
# {'a': 80, 'c': 0, 'b': 10, 'd': 124}
# 9
# ['jnz', 'd', '-5']
# {'a': 80, 'c': 0, 'b': 10, 'd': 124}
# 4
# ['cpy', 'b', 'c']
# {'a': 80, 'c': 10, 'b': 10, 'd': 124}
# 5
# ['sum', 'c', 'a']
# {'a': 90, 'c': 10, 'b': 10, 'd': 124}
# 6
# ['cpy', '0', 'c']
# {'a': 90, 'c': 0, 'b': 10, 'd': 124}
# 7
# ['jnz', 'c', '-2']
# {'a': 90, 'c': 0, 'b': 10, 'd': 124}
# 8
# ['dec', 'd']
# {'a': 90, 'c': 0, 'b': 10, 'd': 123}
# 9
# ['jnz', 'd', '-5']
# {'a': 90, 'c': 0, 'b': 10, 'd': 123}
# 4
# ['cpy', 'b', 'c']
# {'a': 90, 'c': 10, 'b': 10, 'd': 123}
# 5
# ['sum', 'c', 'a']
# {'a': 100, 'c': 10, 'b': 10, 'd': 123}
# 6
# ['cpy', '0', 'c']
# {'a': 100, 'c': 0, 'b': 10, 'd': 123}
# 7
# ['jnz', 'c', '-2']
# {'a': 100, 'c': 0, 'b': 10, 'd': 123}
# 8
# ['dec', 'd']
# {'a': 100, 'c': 0, 'b': 10, 'd': 122}
# 9
# ['jnz', 'd', '-5']
# {'a': 100, 'c': 0, 'b': 10, 'd': 122}
# 4
# ['cpy', 'b', 'c']
# {'a': 100, 'c': 10, 'b': 10, 'd': 122}
# 5
# ['sum', 'c', 'a']
# {'a': 110, 'c': 10, 'b': 10, 'd': 122}
# 6
# ['cpy', '0', 'c']
# {'a': 110, 'c': 0, 'b': 10, 'd': 122}
# 7
# ['jnz', 'c', '-2']
# {'a': 110, 'c': 0, 'b': 10, 'd': 122}
# 8
# ['dec', 'd']
# {'a': 110, 'c': 0, 'b': 10, 'd': 121}
# 9
# ['jnz', 'd', '-5']
# {'a': 110, 'c': 0, 'b': 10, 'd': 121}
# 4
# ['cpy', 'b', 'c']
# {'a': 110, 'c': 10, 'b': 10, 'd': 121}
# 5
# ['sum', 'c', 'a']
# {'a': 120, 'c': 10, 'b': 10, 'd': 121}
# 6
# ['cpy', '0', 'c']
# {'a': 120, 'c': 0, 'b': 10, 'd': 121}
# 7
# ['jnz', 'c', '-2']
# {'a': 120, 'c': 0, 'b': 10, 'd': 121}
# 8
# ['dec', 'd']
# {'a': 120, 'c': 0, 'b': 10, 'd': 120}
# 9
# ['jnz', 'd', '-5']
# {'a': 120, 'c': 0, 'b': 10, 'd': 120}
# 4
# ['cpy', 'b', 'c']
# {'a': 120, 'c': 10, 'b': 10, 'd': 120}
# 5
# ['sum', 'c', 'a']
# {'a': 130, 'c': 10, 'b': 10, 'd': 120}
# 6
# ['cpy', '0', 'c']
# {'a': 130, 'c': 0, 'b': 10, 'd': 120}
# 7
# ['jnz', 'c', '-2']
# {'a': 130, 'c': 0, 'b': 10, 'd': 120}
# 8
# ['dec', 'd']
# {'a': 130, 'c': 0, 'b': 10, 'd': 119}
# 9
# ['jnz', 'd', '-5']
# {'a': 130, 'c': 0, 'b': 10, 'd': 119}
# 4
# ['cpy', 'b', 'c']
# {'a': 130, 'c': 10, 'b': 10, 'd': 119}
# 5
# ['sum', 'c', 'a']
# {'a': 140, 'c': 10, 'b': 10, 'd': 119}
# 6
# ['cpy', '0', 'c']
# {'a': 140, 'c': 0, 'b': 10, 'd': 119}
# 7
# ['jnz', 'c', '-2']
# {'a': 140, 'c': 0, 'b': 10, 'd': 119}
# 8
# ['dec', 'd']
# {'a': 140, 'c': 0, 'b': 10, 'd': 118}
# 9
# ['jnz', 'd', '-5']
# {'a': 140, 'c': 0, 'b': 10, 'd': 118}
# 4
# ['cpy', 'b', 'c']
# {'a': 140, 'c': 10, 'b': 10, 'd': 118}
# 5
# ['sum', 'c', 'a']
# {'a': 150, 'c': 10, 'b': 10, 'd': 118}
# 6
# ['cpy', '0', 'c']
# {'a': 150, 'c': 0, 'b': 10, 'd': 118}
# 7
# ['jnz', 'c', '-2']
# {'a': 150, 'c': 0, 'b': 10, 'd': 118}
# 8
# ['dec', 'd']
# {'a': 150, 'c': 0, 'b': 10, 'd': 117}
# 9
# ['jnz', 'd', '-5']
# {'a': 150, 'c': 0, 'b': 10, 'd': 117}
# 4
# ['cpy', 'b', 'c']
# {'a': 150, 'c': 10, 'b': 10, 'd': 117}
# 5
# ['sum', 'c', 'a']
# {'a': 160, 'c': 10, 'b': 10, 'd': 117}
# 6
# ['cpy', '0', 'c']
# {'a': 160, 'c': 0, 'b': 10, 'd': 117}
# 7
# ['jnz', 'c', '-2']
# {'a': 160, 'c': 0, 'b': 10, 'd': 117}
# 8
# ['dec', 'd']
# {'a': 160, 'c': 0, 'b': 10, 'd': 116}
# 9
# ['jnz', 'd', '-5']
# {'a': 160, 'c': 0, 'b': 10, 'd': 116}
# 4
# ['cpy', 'b', 'c']
# {'a': 160, 'c': 10, 'b': 10, 'd': 116}
# 5
# ['sum', 'c', 'a']
# {'a': 170, 'c': 10, 'b': 10, 'd': 116}
# 6
# ['cpy', '0', 'c']
# {'a': 170, 'c': 0, 'b': 10, 'd': 116}
# 7
# ['jnz', 'c', '-2']
# {'a': 170, 'c': 0, 'b': 10, 'd': 116}
# 8
# ['dec', 'd']
# {'a': 170, 'c': 0, 'b': 10, 'd': 115}
# 9
# ['jnz', 'd', '-5']
# {'a': 170, 'c': 0, 'b': 10, 'd': 115}
# 4
# ['cpy', 'b', 'c']
# {'a': 170, 'c': 10, 'b': 10, 'd': 115}
# 5
# ['sum', 'c', 'a']
# {'a': 180, 'c': 10, 'b': 10, 'd': 115}
# 6
# ['cpy', '0', 'c']
# {'a': 180, 'c': 0, 'b': 10, 'd': 115}
# 7
# ['jnz', 'c', '-2']
# {'a': 180, 'c': 0, 'b': 10, 'd': 115}
# 8
# ['dec', 'd']
# {'a': 180, 'c': 0, 'b': 10, 'd': 114}
# 9
# ['jnz', 'd', '-5']
# {'a': 180, 'c': 0, 'b': 10, 'd': 114}
# 4
# ['cpy', 'b', 'c']
# {'a': 180, 'c': 10, 'b': 10, 'd': 114}
# 5
# ['sum', 'c', 'a']
# {'a': 190, 'c': 10, 'b': 10, 'd': 114}
# 6
# ['cpy', '0', 'c']
# {'a': 190, 'c': 0, 'b': 10, 'd': 114}
# 7
# ['jnz', 'c', '-2']
# {'a': 190, 'c': 0, 'b': 10, 'd': 114}
# 8
# ['dec', 'd']
# {'a': 190, 'c': 0, 'b': 10, 'd': 113}
# 9
# ['jnz', 'd', '-5']
# {'a': 190, 'c': 0, 'b': 10, 'd': 113}
# 4
# ['cpy', 'b', 'c']
# {'a': 190, 'c': 10, 'b': 10, 'd': 113}
# 5
# ['sum', 'c', 'a']
# {'a': 200, 'c': 10, 'b': 10, 'd': 113}
# 6
# ['cpy', '0', 'c']
# {'a': 200, 'c': 0, 'b': 10, 'd': 113}
# 7
# ['jnz', 'c', '-2']
# {'a': 200, 'c': 0, 'b': 10, 'd': 113}
# 8
# ['dec', 'd']
# {'a': 200, 'c': 0, 'b': 10, 'd': 112}
# 9
# ['jnz', 'd', '-5']
# {'a': 200, 'c': 0, 'b': 10, 'd': 112}
# 4
# ['cpy', 'b', 'c']
# {'a': 200, 'c': 10, 'b': 10, 'd': 112}
# 5
# ['sum', 'c', 'a']
# {'a': 210, 'c': 10, 'b': 10, 'd': 112}
# 6
# ['cpy', '0', 'c']
# {'a': 210, 'c': 0, 'b': 10, 'd': 112}
# 7
# ['jnz', 'c', '-2']
# {'a': 210, 'c': 0, 'b': 10, 'd': 112}
# 8
# ['dec', 'd']
# {'a': 210, 'c': 0, 'b': 10, 'd': 111}
# 9
# ['jnz', 'd', '-5']
# {'a': 210, 'c': 0, 'b': 10, 'd': 111}
# 4
# ['cpy', 'b', 'c']
# {'a': 210, 'c': 10, 'b': 10, 'd': 111}
# 5
# ['sum', 'c', 'a']
# {'a': 220, 'c': 10, 'b': 10, 'd': 111}
# 6
# ['cpy', '0', 'c']
# {'a': 220, 'c': 0, 'b': 10, 'd': 111}
# 7
# ['jnz', 'c', '-2']
# {'a': 220, 'c': 0, 'b': 10, 'd': 111}
# 8
# ['dec', 'd']
# {'a': 220, 'c': 0, 'b': 10, 'd': 110}
# 9
# ['jnz', 'd', '-5']
# {'a': 220, 'c': 0, 'b': 10, 'd': 110}
# 4
# ['cpy', 'b', 'c']
# {'a': 220, 'c': 10, 'b': 10, 'd': 110}
# 5
# ['sum', 'c', 'a']
# {'a': 230, 'c': 10, 'b': 10, 'd': 110}
# 6
# ['cpy', '0', 'c']
# {'a': 230, 'c': 0, 'b': 10, 'd': 110}
# 7
# ['jnz', 'c', '-2']
# {'a': 230, 'c': 0, 'b': 10, 'd': 110}
# 8
# ['dec', 'd']
# {'a': 230, 'c': 0, 'b': 10, 'd': 109}
# 9
# ['jnz', 'd', '-5']
# {'a': 230, 'c': 0, 'b': 10, 'd': 109}
# 4
# ['cpy', 'b', 'c']
# {'a': 230, 'c': 10, 'b': 10, 'd': 109}
# 5
# ['sum', 'c', 'a']
# {'a': 240, 'c': 10, 'b': 10, 'd': 109}
# 6
# ['cpy', '0', 'c']
# {'a': 240, 'c': 0, 'b': 10, 'd': 109}
# 7
# ['jnz', 'c', '-2']
# {'a': 240, 'c': 0, 'b': 10, 'd': 109}
# 8
# ['dec', 'd']
# {'a': 240, 'c': 0, 'b': 10, 'd': 108}
# 9
# ['jnz', 'd', '-5']
# {'a': 240, 'c': 0, 'b': 10, 'd': 108}
# 4
# ['cpy', 'b', 'c']
# {'a': 240, 'c': 10, 'b': 10, 'd': 108}
# 5
# ['sum', 'c', 'a']
# {'a': 250, 'c': 10, 'b': 10, 'd': 108}
# 6
# ['cpy', '0', 'c']
# {'a': 250, 'c': 0, 'b': 10, 'd': 108}
# 7
# ['jnz', 'c', '-2']
# {'a': 250, 'c': 0, 'b': 10, 'd': 108}
# 8
# ['dec', 'd']
# {'a': 250, 'c': 0, 'b': 10, 'd': 107}
# 9
# ['jnz', 'd', '-5']
# {'a': 250, 'c': 0, 'b': 10, 'd': 107}
# 4
# ['cpy', 'b', 'c']
# {'a': 250, 'c': 10, 'b': 10, 'd': 107}
# 5
# ['sum', 'c', 'a']
# {'a': 260, 'c': 10, 'b': 10, 'd': 107}
# 6
# ['cpy', '0', 'c']
# {'a': 260, 'c': 0, 'b': 10, 'd': 107}
# 7
# ['jnz', 'c', '-2']
# {'a': 260, 'c': 0, 'b': 10, 'd': 107}
# 8
# ['dec', 'd']
# {'a': 260, 'c': 0, 'b': 10, 'd': 106}
# 9
# ['jnz', 'd', '-5']
# {'a': 260, 'c': 0, 'b': 10, 'd': 106}
# 4
# ['cpy', 'b', 'c']
# {'a': 260, 'c': 10, 'b': 10, 'd': 106}
# 5
# ['sum', 'c', 'a']
# {'a': 270, 'c': 10, 'b': 10, 'd': 106}
# 6
# ['cpy', '0', 'c']
# {'a': 270, 'c': 0, 'b': 10, 'd': 106}
# 7
# ['jnz', 'c', '-2']
# {'a': 270, 'c': 0, 'b': 10, 'd': 106}
# 8
# ['dec', 'd']
# {'a': 270, 'c': 0, 'b': 10, 'd': 105}
# 9
# ['jnz', 'd', '-5']
# {'a': 270, 'c': 0, 'b': 10, 'd': 105}
# 4
# ['cpy', 'b', 'c']
# {'a': 270, 'c': 10, 'b': 10, 'd': 105}
# 5
# ['sum', 'c', 'a']
# {'a': 280, 'c': 10, 'b': 10, 'd': 105}
# 6
# ['cpy', '0', 'c']
# {'a': 280, 'c': 0, 'b': 10, 'd': 105}
# 7
# ['jnz', 'c', '-2']
# {'a': 280, 'c': 0, 'b': 10, 'd': 105}
# 8
# ['dec', 'd']
# {'a': 280, 'c': 0, 'b': 10, 'd': 104}
# 9
# ['jnz', 'd', '-5']
# {'a': 280, 'c': 0, 'b': 10, 'd': 104}
# 4
# ['cpy', 'b', 'c']
# {'a': 280, 'c': 10, 'b': 10, 'd': 104}
# 5
# ['sum', 'c', 'a']
# {'a': 290, 'c': 10, 'b': 10, 'd': 104}
# 6
# ['cpy', '0', 'c']
# {'a': 290, 'c': 0, 'b': 10, 'd': 104}
# 7
# ['jnz', 'c', '-2']
# {'a': 290, 'c': 0, 'b': 10, 'd': 104}
# 8
# ['dec', 'd']
# {'a': 290, 'c': 0, 'b': 10, 'd': 103}
# 9
# ['jnz', 'd', '-5']
# {'a': 290, 'c': 0, 'b': 10, 'd': 103}
# 4
# ['cpy', 'b', 'c']
# {'a': 290, 'c': 10, 'b': 10, 'd': 103}
# 5
# ['sum', 'c', 'a']
# {'a': 300, 'c': 10, 'b': 10, 'd': 103}
# 6
# ['cpy', '0', 'c']
# {'a': 300, 'c': 0, 'b': 10, 'd': 103}
# 7
# ['jnz', 'c', '-2']
# {'a': 300, 'c': 0, 'b': 10, 'd': 103}
# 8
# ['dec', 'd']
# {'a': 300, 'c': 0, 'b': 10, 'd': 102}
# 9
# ['jnz', 'd', '-5']
# {'a': 300, 'c': 0, 'b': 10, 'd': 102}
# 4
# ['cpy', 'b', 'c']
# {'a': 300, 'c': 10, 'b': 10, 'd': 102}
# 5
# ['sum', 'c', 'a']
# {'a': 310, 'c': 10, 'b': 10, 'd': 102}
# 6
# ['cpy', '0', 'c']
# {'a': 310, 'c': 0, 'b': 10, 'd': 102}
# 7
# ['jnz', 'c', '-2']
# {'a': 310, 'c': 0, 'b': 10, 'd': 102}
# 8
# ['dec', 'd']
# {'a': 310, 'c': 0, 'b': 10, 'd': 101}
# 9
# ['jnz', 'd', '-5']
# {'a': 310, 'c': 0, 'b': 10, 'd': 101}
# 4
# ['cpy', 'b', 'c']
# {'a': 310, 'c': 10, 'b': 10, 'd': 101}
# 5
# ['sum', 'c', 'a']
# {'a': 320, 'c': 10, 'b': 10, 'd': 101}
# 6
# ['cpy', '0', 'c']
# {'a': 320, 'c': 0, 'b': 10, 'd': 101}
# 7
# ['jnz', 'c', '-2']
# {'a': 320, 'c': 0, 'b': 10, 'd': 101}
# 8
# ['dec', 'd']
# {'a': 320, 'c': 0, 'b': 10, 'd': 100}
# 9
# ['jnz', 'd', '-5']
# {'a': 320, 'c': 0, 'b': 10, 'd': 100}
# 4
# ['cpy', 'b', 'c']
# {'a': 320, 'c': 10, 'b': 10, 'd': 100}
# 5
# ['sum', 'c', 'a']
# {'a': 330, 'c': 10, 'b': 10, 'd': 100}
# 6
# ['cpy', '0', 'c']
# {'a': 330, 'c': 0, 'b': 10, 'd': 100}
# 7
# ['jnz', 'c', '-2']
# {'a': 330, 'c': 0, 'b': 10, 'd': 100}
# 8
# ['dec', 'd']
# {'a': 330, 'c': 0, 'b': 10, 'd': 99}
# 9
# ['jnz', 'd', '-5']
# {'a': 330, 'c': 0, 'b': 10, 'd': 99}
# 4
# ['cpy', 'b', 'c']
# {'a': 330, 'c': 10, 'b': 10, 'd': 99}
# 5
# ['sum', 'c', 'a']
# {'a': 340, 'c': 10, 'b': 10, 'd': 99}
# 6
# ['cpy', '0', 'c']
# {'a': 340, 'c': 0, 'b': 10, 'd': 99}
# 7
# ['jnz', 'c', '-2']
# {'a': 340, 'c': 0, 'b': 10, 'd': 99}
# 8
# ['dec', 'd']
# {'a': 340, 'c': 0, 'b': 10, 'd': 98}
# 9
# ['jnz', 'd', '-5']
# {'a': 340, 'c': 0, 'b': 10, 'd': 98}
# 4
# ['cpy', 'b', 'c']
# {'a': 340, 'c': 10, 'b': 10, 'd': 98}
# 5
# ['sum', 'c', 'a']
# {'a': 350, 'c': 10, 'b': 10, 'd': 98}
# 6
# ['cpy', '0', 'c']
# {'a': 350, 'c': 0, 'b': 10, 'd': 98}
# 7
# ['jnz', 'c', '-2']
# {'a': 350, 'c': 0, 'b': 10, 'd': 98}
# 8
# ['dec', 'd']
# {'a': 350, 'c': 0, 'b': 10, 'd': 97}
# 9
# ['jnz', 'd', '-5']
# {'a': 350, 'c': 0, 'b': 10, 'd': 97}
# 4
# ['cpy', 'b', 'c']
# {'a': 350, 'c': 10, 'b': 10, 'd': 97}
# 5
# ['sum', 'c', 'a']
# {'a': 360, 'c': 10, 'b': 10, 'd': 97}
# 6
# ['cpy', '0', 'c']
# {'a': 360, 'c': 0, 'b': 10, 'd': 97}
# 7
# ['jnz', 'c', '-2']
# {'a': 360, 'c': 0, 'b': 10, 'd': 97}
# 8
# ['dec', 'd']
# {'a': 360, 'c': 0, 'b': 10, 'd': 96}
# 9
# ['jnz', 'd', '-5']
# {'a': 360, 'c': 0, 'b': 10, 'd': 96}
# 4
# ['cpy', 'b', 'c']
# {'a': 360, 'c': 10, 'b': 10, 'd': 96}
# 5
# ['sum', 'c', 'a']
# {'a': 370, 'c': 10, 'b': 10, 'd': 96}
# 6
# ['cpy', '0', 'c']
# {'a': 370, 'c': 0, 'b': 10, 'd': 96}
# 7
# ['jnz', 'c', '-2']
# {'a': 370, 'c': 0, 'b': 10, 'd': 96}
# 8
# ['dec', 'd']
# {'a': 370, 'c': 0, 'b': 10, 'd': 95}
# 9
# ['jnz', 'd', '-5']
# {'a': 370, 'c': 0, 'b': 10, 'd': 95}
# 4
# ['cpy', 'b', 'c']
# {'a': 370, 'c': 10, 'b': 10, 'd': 95}
# 5
# ['sum', 'c', 'a']
# {'a': 380, 'c': 10, 'b': 10, 'd': 95}
# 6
# ['cpy', '0', 'c']
# {'a': 380, 'c': 0, 'b': 10, 'd': 95}
# 7
# ['jnz', 'c', '-2']
# {'a': 380, 'c': 0, 'b': 10, 'd': 95}
# 8
# ['dec', 'd']
# {'a': 380, 'c': 0, 'b': 10, 'd': 94}
# 9
# ['jnz', 'd', '-5']
# {'a': 380, 'c': 0, 'b': 10, 'd': 94}
# 4
# ['cpy', 'b', 'c']
# {'a': 380, 'c': 10, 'b': 10, 'd': 94}
# 5
# ['sum', 'c', 'a']
# {'a': 390, 'c': 10, 'b': 10, 'd': 94}
# 6
# ['cpy', '0', 'c']
# {'a': 390, 'c': 0, 'b': 10, 'd': 94}
# 7
# ['jnz', 'c', '-2']
# {'a': 390, 'c': 0, 'b': 10, 'd': 94}
# 8
# ['dec', 'd']
# {'a': 390, 'c': 0, 'b': 10, 'd': 93}
# 9
# ['jnz', 'd', '-5']
# {'a': 390, 'c': 0, 'b': 10, 'd': 93}
# 4
# ['cpy', 'b', 'c']
# {'a': 390, 'c': 10, 'b': 10, 'd': 93}
# 5
# ['sum', 'c', 'a']
# {'a': 400, 'c': 10, 'b': 10, 'd': 93}
# 6
# ['cpy', '0', 'c']
# {'a': 400, 'c': 0, 'b': 10, 'd': 93}
# 7
# ['jnz', 'c', '-2']
# {'a': 400, 'c': 0, 'b': 10, 'd': 93}
# 8
# ['dec', 'd']
# {'a': 400, 'c': 0, 'b': 10, 'd': 92}
# 9
# ['jnz', 'd', '-5']
# {'a': 400, 'c': 0, 'b': 10, 'd': 92}
# 4
# ['cpy', 'b', 'c']
# {'a': 400, 'c': 10, 'b': 10, 'd': 92}
# 5
# ['sum', 'c', 'a']
# {'a': 410, 'c': 10, 'b': 10, 'd': 92}
# 6
# ['cpy', '0', 'c']
# {'a': 410, 'c': 0, 'b': 10, 'd': 92}
# 7
# ['jnz', 'c', '-2']
# {'a': 410, 'c': 0, 'b': 10, 'd': 92}
# 8
# ['dec', 'd']
# {'a': 410, 'c': 0, 'b': 10, 'd': 91}
# 9
# ['jnz', 'd', '-5']
# {'a': 410, 'c': 0, 'b': 10, 'd': 91}
# 4
# ['cpy', 'b', 'c']
# {'a': 410, 'c': 10, 'b': 10, 'd': 91}
# 5
# ['sum', 'c', 'a']
# {'a': 420, 'c': 10, 'b': 10, 'd': 91}
# 6
# ['cpy', '0', 'c']
# {'a': 420, 'c': 0, 'b': 10, 'd': 91}
# 7
# ['jnz', 'c', '-2']
# {'a': 420, 'c': 0, 'b': 10, 'd': 91}
# 8
# ['dec', 'd']
# {'a': 420, 'c': 0, 'b': 10, 'd': 90}
# 9
# ['jnz', 'd', '-5']
# {'a': 420, 'c': 0, 'b': 10, 'd': 90}
# 4
# ['cpy', 'b', 'c']
# {'a': 420, 'c': 10, 'b': 10, 'd': 90}
# 5
# ['sum', 'c', 'a']
# {'a': 430, 'c': 10, 'b': 10, 'd': 90}
# 6
# ['cpy', '0', 'c']
# {'a': 430, 'c': 0, 'b': 10, 'd': 90}
# 7
# ['jnz', 'c', '-2']
# {'a': 430, 'c': 0, 'b': 10, 'd': 90}
# 8
# ['dec', 'd']
# {'a': 430, 'c': 0, 'b': 10, 'd': 89}
# 9
# ['jnz', 'd', '-5']
# {'a': 430, 'c': 0, 'b': 10, 'd': 89}
# 4
# ['cpy', 'b', 'c']
# {'a': 430, 'c': 10, 'b': 10, 'd': 89}
# 5
# ['sum', 'c', 'a']
# {'a': 440, 'c': 10, 'b': 10, 'd': 89}
# 6
# ['cpy', '0', 'c']
# {'a': 440, 'c': 0, 'b': 10, 'd': 89}
# 7
# ['jnz', 'c', '-2']
# {'a': 440, 'c': 0, 'b': 10, 'd': 89}
# 8
# ['dec', 'd']
# {'a': 440, 'c': 0, 'b': 10, 'd': 88}
# 9
# ['jnz', 'd', '-5']
# {'a': 440, 'c': 0, 'b': 10, 'd': 88}
# 4
# ['cpy', 'b', 'c']
# {'a': 440, 'c': 10, 'b': 10, 'd': 88}
# 5
# ['sum', 'c', 'a']
# {'a': 450, 'c': 10, 'b': 10, 'd': 88}
# 6
# ['cpy', '0', 'c']
# {'a': 450, 'c': 0, 'b': 10, 'd': 88}
# 7
# ['jnz', 'c', '-2']
# {'a': 450, 'c': 0, 'b': 10, 'd': 88}
# 8
# ['dec', 'd']
# {'a': 450, 'c': 0, 'b': 10, 'd': 87}
# 9
# ['jnz', 'd', '-5']
# {'a': 450, 'c': 0, 'b': 10, 'd': 87}
# 4
# ['cpy', 'b', 'c']
# {'a': 450, 'c': 10, 'b': 10, 'd': 87}
# 5
# ['sum', 'c', 'a']
# {'a': 460, 'c': 10, 'b': 10, 'd': 87}
# 6
# ['cpy', '0', 'c']
# {'a': 460, 'c': 0, 'b': 10, 'd': 87}
# 7
# ['jnz', 'c', '-2']
# {'a': 460, 'c': 0, 'b': 10, 'd': 87}
# 8
# ['dec', 'd']
# {'a': 460, 'c': 0, 'b': 10, 'd': 86}
# 9
# ['jnz', 'd', '-5']
# {'a': 460, 'c': 0, 'b': 10, 'd': 86}
# 4
# ['cpy', 'b', 'c']
# {'a': 460, 'c': 10, 'b': 10, 'd': 86}
# 5
# ['sum', 'c', 'a']
# {'a': 470, 'c': 10, 'b': 10, 'd': 86}
# 6
# ['cpy', '0', 'c']
# {'a': 470, 'c': 0, 'b': 10, 'd': 86}
# 7
# ['jnz', 'c', '-2']
# {'a': 470, 'c': 0, 'b': 10, 'd': 86}
# 8
# ['dec', 'd']
# {'a': 470, 'c': 0, 'b': 10, 'd': 85}
# 9
# ['jnz', 'd', '-5']
# {'a': 470, 'c': 0, 'b': 10, 'd': 85}
# 4
# ['cpy', 'b', 'c']
# {'a': 470, 'c': 10, 'b': 10, 'd': 85}
# 5
# ['sum', 'c', 'a']
# {'a': 480, 'c': 10, 'b': 10, 'd': 85}
# 6
# ['cpy', '0', 'c']
# {'a': 480, 'c': 0, 'b': 10, 'd': 85}
# 7
# ['jnz', 'c', '-2']
# {'a': 480, 'c': 0, 'b': 10, 'd': 85}
# 8
# ['dec', 'd']
# {'a': 480, 'c': 0, 'b': 10, 'd': 84}
# 9
# ['jnz', 'd', '-5']
# {'a': 480, 'c': 0, 'b': 10, 'd': 84}
# 4
# ['cpy', 'b', 'c']
# {'a': 480, 'c': 10, 'b': 10, 'd': 84}
# 5
# ['sum', 'c', 'a']
# {'a': 490, 'c': 10, 'b': 10, 'd': 84}
# 6
# ['cpy', '0', 'c']
# {'a': 490, 'c': 0, 'b': 10, 'd': 84}
# 7
# ['jnz', 'c', '-2']
# {'a': 490, 'c': 0, 'b': 10, 'd': 84}
# 8
# ['dec', 'd']
# {'a': 490, 'c': 0, 'b': 10, 'd': 83}
# 9
# ['jnz', 'd', '-5']
# {'a': 490, 'c': 0, 'b': 10, 'd': 83}
# 4
# ['cpy', 'b', 'c']
# {'a': 490, 'c': 10, 'b': 10, 'd': 83}
# 5
# ['sum', 'c', 'a']
# {'a': 500, 'c': 10, 'b': 10, 'd': 83}
# 6
# ['cpy', '0', 'c']
# {'a': 500, 'c': 0, 'b': 10, 'd': 83}
# 7
# ['jnz', 'c', '-2']
# {'a': 500, 'c': 0, 'b': 10, 'd': 83}
# 8
# ['dec', 'd']
# {'a': 500, 'c': 0, 'b': 10, 'd': 82}
# 9
# ['jnz', 'd', '-5']
# {'a': 500, 'c': 0, 'b': 10, 'd': 82}
# 4
# ['cpy', 'b', 'c']
# {'a': 500, 'c': 10, 'b': 10, 'd': 82}
# 5
# ['sum', 'c', 'a']
# {'a': 510, 'c': 10, 'b': 10, 'd': 82}
# 6
# ['cpy', '0', 'c']
# {'a': 510, 'c': 0, 'b': 10, 'd': 82}
# 7
# ['jnz', 'c', '-2']
# {'a': 510, 'c': 0, 'b': 10, 'd': 82}
# 8
# ['dec', 'd']
# {'a': 510, 'c': 0, 'b': 10, 'd': 81}
# 9
# ['jnz', 'd', '-5']
# {'a': 510, 'c': 0, 'b': 10, 'd': 81}
# 4
# ['cpy', 'b', 'c']
# {'a': 510, 'c': 10, 'b': 10, 'd': 81}
# 5
# ['sum', 'c', 'a']
# {'a': 520, 'c': 10, 'b': 10, 'd': 81}
# 6
# ['cpy', '0', 'c']
# {'a': 520, 'c': 0, 'b': 10, 'd': 81}
# 7
# ['jnz', 'c', '-2']
# {'a': 520, 'c': 0, 'b': 10, 'd': 81}
# 8
# ['dec', 'd']
# {'a': 520, 'c': 0, 'b': 10, 'd': 80}
# 9
# ['jnz', 'd', '-5']
# {'a': 520, 'c': 0, 'b': 10, 'd': 80}
# 4
# ['cpy', 'b', 'c']
# {'a': 520, 'c': 10, 'b': 10, 'd': 80}
# 5
# ['sum', 'c', 'a']
# {'a': 530, 'c': 10, 'b': 10, 'd': 80}
# 6
# ['cpy', '0', 'c']
# {'a': 530, 'c': 0, 'b': 10, 'd': 80}
# 7
# ['jnz', 'c', '-2']
# {'a': 530, 'c': 0, 'b': 10, 'd': 80}
# 8
# ['dec', 'd']
# {'a': 530, 'c': 0, 'b': 10, 'd': 79}
# 9
# ['jnz', 'd', '-5']
# {'a': 530, 'c': 0, 'b': 10, 'd': 79}
# 4
# ['cpy', 'b', 'c']
# {'a': 530, 'c': 10, 'b': 10, 'd': 79}
# 5
# ['sum', 'c', 'a']
# {'a': 540, 'c': 10, 'b': 10, 'd': 79}
# 6
# ['cpy', '0', 'c']
# {'a': 540, 'c': 0, 'b': 10, 'd': 79}
# 7
# ['jnz', 'c', '-2']
# {'a': 540, 'c': 0, 'b': 10, 'd': 79}
# 8
# ['dec', 'd']
# {'a': 540, 'c': 0, 'b': 10, 'd': 78}
# 9
# ['jnz', 'd', '-5']
# {'a': 540, 'c': 0, 'b': 10, 'd': 78}
# 4
# ['cpy', 'b', 'c']
# {'a': 540, 'c': 10, 'b': 10, 'd': 78}
# 5
# ['sum', 'c', 'a']
# {'a': 550, 'c': 10, 'b': 10, 'd': 78}
# 6
# ['cpy', '0', 'c']
# {'a': 550, 'c': 0, 'b': 10, 'd': 78}
# 7
# ['jnz', 'c', '-2']
# {'a': 550, 'c': 0, 'b': 10, 'd': 78}
# 8
# ['dec', 'd']
# {'a': 550, 'c': 0, 'b': 10, 'd': 77}
# 9
# ['jnz', 'd', '-5']
# {'a': 550, 'c': 0, 'b': 10, 'd': 77}
# 4
# ['cpy', 'b', 'c']
# {'a': 550, 'c': 10, 'b': 10, 'd': 77}
# 5
# ['sum', 'c', 'a']
# {'a': 560, 'c': 10, 'b': 10, 'd': 77}
# 6
# ['cpy', '0', 'c']
# {'a': 560, 'c': 0, 'b': 10, 'd': 77}
# 7
# ['jnz', 'c', '-2']
# {'a': 560, 'c': 0, 'b': 10, 'd': 77}
# 8
# ['dec', 'd']
# {'a': 560, 'c': 0, 'b': 10, 'd': 76}
# 9
# ['jnz', 'd', '-5']
# {'a': 560, 'c': 0, 'b': 10, 'd': 76}
# 4
# ['cpy', 'b', 'c']
# {'a': 560, 'c': 10, 'b': 10, 'd': 76}
# 5
# ['sum', 'c', 'a']
# {'a': 570, 'c': 10, 'b': 10, 'd': 76}
# 6
# ['cpy', '0', 'c']
# {'a': 570, 'c': 0, 'b': 10, 'd': 76}
# 7
# ['jnz', 'c', '-2']
# {'a': 570, 'c': 0, 'b': 10, 'd': 76}
# 8
# ['dec', 'd']
# {'a': 570, 'c': 0, 'b': 10, 'd': 75}
# 9
# ['jnz', 'd', '-5']
# {'a': 570, 'c': 0, 'b': 10, 'd': 75}
# 4
# ['cpy', 'b', 'c']
# {'a': 570, 'c': 10, 'b': 10, 'd': 75}
# 5
# ['sum', 'c', 'a']
# {'a': 580, 'c': 10, 'b': 10, 'd': 75}
# 6
# ['cpy', '0', 'c']
# {'a': 580, 'c': 0, 'b': 10, 'd': 75}
# 7
# ['jnz', 'c', '-2']
# {'a': 580, 'c': 0, 'b': 10, 'd': 75}
# 8
# ['dec', 'd']
# {'a': 580, 'c': 0, 'b': 10, 'd': 74}
# 9
# ['jnz', 'd', '-5']
# {'a': 580, 'c': 0, 'b': 10, 'd': 74}
# 4
# ['cpy', 'b', 'c']
# {'a': 580, 'c': 10, 'b': 10, 'd': 74}
# 5
# ['sum', 'c', 'a']
# {'a': 590, 'c': 10, 'b': 10, 'd': 74}
# 6
# ['cpy', '0', 'c']
# {'a': 590, 'c': 0, 'b': 10, 'd': 74}
# 7
# ['jnz', 'c', '-2']
# {'a': 590, 'c': 0, 'b': 10, 'd': 74}
# 8
# ['dec', 'd']
# {'a': 590, 'c': 0, 'b': 10, 'd': 73}
# 9
# ['jnz', 'd', '-5']
# {'a': 590, 'c': 0, 'b': 10, 'd': 73}
# 4
# ['cpy', 'b', 'c']
# {'a': 590, 'c': 10, 'b': 10, 'd': 73}
# 5
# ['sum', 'c', 'a']
# {'a': 600, 'c': 10, 'b': 10, 'd': 73}
# 6
# ['cpy', '0', 'c']
# {'a': 600, 'c': 0, 'b': 10, 'd': 73}
# 7
# ['jnz', 'c', '-2']
# {'a': 600, 'c': 0, 'b': 10, 'd': 73}
# 8
# ['dec', 'd']
# {'a': 600, 'c': 0, 'b': 10, 'd': 72}
# 9
# ['jnz', 'd', '-5']
# {'a': 600, 'c': 0, 'b': 10, 'd': 72}
# 4
# ['cpy', 'b', 'c']
# {'a': 600, 'c': 10, 'b': 10, 'd': 72}
# 5
# ['sum', 'c', 'a']
# {'a': 610, 'c': 10, 'b': 10, 'd': 72}
# 6
# ['cpy', '0', 'c']
# {'a': 610, 'c': 0, 'b': 10, 'd': 72}
# 7
# ['jnz', 'c', '-2']
# {'a': 610, 'c': 0, 'b': 10, 'd': 72}
# 8
# ['dec', 'd']
# {'a': 610, 'c': 0, 'b': 10, 'd': 71}
# 9
# ['jnz', 'd', '-5']
# {'a': 610, 'c': 0, 'b': 10, 'd': 71}
# 4
# ['cpy', 'b', 'c']
# {'a': 610, 'c': 10, 'b': 10, 'd': 71}
# 5
# ['sum', 'c', 'a']
# {'a': 620, 'c': 10, 'b': 10, 'd': 71}
# 6
# ['cpy', '0', 'c']
# {'a': 620, 'c': 0, 'b': 10, 'd': 71}
# 7
# ['jnz', 'c', '-2']
# {'a': 620, 'c': 0, 'b': 10, 'd': 71}
# 8
# ['dec', 'd']
# {'a': 620, 'c': 0, 'b': 10, 'd': 70}
# 9
# ['jnz', 'd', '-5']
# {'a': 620, 'c': 0, 'b': 10, 'd': 70}
# 4
# ['cpy', 'b', 'c']
# {'a': 620, 'c': 10, 'b': 10, 'd': 70}
# 5
# ['sum', 'c', 'a']
# {'a': 630, 'c': 10, 'b': 10, 'd': 70}
# 6
# ['cpy', '0', 'c']
# {'a': 630, 'c': 0, 'b': 10, 'd': 70}
# 7
# ['jnz', 'c', '-2']
# {'a': 630, 'c': 0, 'b': 10, 'd': 70}
# 8
# ['dec', 'd']
# {'a': 630, 'c': 0, 'b': 10, 'd': 69}
# 9
# ['jnz', 'd', '-5']
# {'a': 630, 'c': 0, 'b': 10, 'd': 69}
# 4
# ['cpy', 'b', 'c']
# {'a': 630, 'c': 10, 'b': 10, 'd': 69}
# 5
# ['sum', 'c', 'a']
# {'a': 640, 'c': 10, 'b': 10, 'd': 69}
# 6
# ['cpy', '0', 'c']
# {'a': 640, 'c': 0, 'b': 10, 'd': 69}
# 7
# ['jnz', 'c', '-2']
# {'a': 640, 'c': 0, 'b': 10, 'd': 69}
# 8
# ['dec', 'd']
# {'a': 640, 'c': 0, 'b': 10, 'd': 68}
# 9
# ['jnz', 'd', '-5']
# {'a': 640, 'c': 0, 'b': 10, 'd': 68}
# 4
# ['cpy', 'b', 'c']
# {'a': 640, 'c': 10, 'b': 10, 'd': 68}
# 5
# ['sum', 'c', 'a']
# {'a': 650, 'c': 10, 'b': 10, 'd': 68}
# 6
# ['cpy', '0', 'c']
# {'a': 650, 'c': 0, 'b': 10, 'd': 68}
# 7
# ['jnz', 'c', '-2']
# {'a': 650, 'c': 0, 'b': 10, 'd': 68}
# 8
# ['dec', 'd']
# {'a': 650, 'c': 0, 'b': 10, 'd': 67}
# 9
# ['jnz', 'd', '-5']
# {'a': 650, 'c': 0, 'b': 10, 'd': 67}
# 4
# ['cpy', 'b', 'c']
# {'a': 650, 'c': 10, 'b': 10, 'd': 67}
# 5
# ['sum', 'c', 'a']
# {'a': 660, 'c': 10, 'b': 10, 'd': 67}
# 6
# ['cpy', '0', 'c']
# {'a': 660, 'c': 0, 'b': 10, 'd': 67}
# 7
# ['jnz', 'c', '-2']
# {'a': 660, 'c': 0, 'b': 10, 'd': 67}
# 8
# ['dec', 'd']
# {'a': 660, 'c': 0, 'b': 10, 'd': 66}
# 9
# ['jnz', 'd', '-5']
# {'a': 660, 'c': 0, 'b': 10, 'd': 66}
# 4
# ['cpy', 'b', 'c']
# {'a': 660, 'c': 10, 'b': 10, 'd': 66}
# 5
# ['sum', 'c', 'a']
# {'a': 670, 'c': 10, 'b': 10, 'd': 66}
# 6
# ['cpy', '0', 'c']
# {'a': 670, 'c': 0, 'b': 10, 'd': 66}
# 7
# ['jnz', 'c', '-2']
# {'a': 670, 'c': 0, 'b': 10, 'd': 66}
# 8
# ['dec', 'd']
# {'a': 670, 'c': 0, 'b': 10, 'd': 65}
# 9
# ['jnz', 'd', '-5']
# {'a': 670, 'c': 0, 'b': 10, 'd': 65}
# 4
# ['cpy', 'b', 'c']
# {'a': 670, 'c': 10, 'b': 10, 'd': 65}
# 5
# ['sum', 'c', 'a']
# {'a': 680, 'c': 10, 'b': 10, 'd': 65}
# 6
# ['cpy', '0', 'c']
# {'a': 680, 'c': 0, 'b': 10, 'd': 65}
# 7
# ['jnz', 'c', '-2']
# {'a': 680, 'c': 0, 'b': 10, 'd': 65}
# 8
# ['dec', 'd']
# {'a': 680, 'c': 0, 'b': 10, 'd': 64}
# 9
# ['jnz', 'd', '-5']
# {'a': 680, 'c': 0, 'b': 10, 'd': 64}
# 4
# ['cpy', 'b', 'c']
# {'a': 680, 'c': 10, 'b': 10, 'd': 64}
# 5
# ['sum', 'c', 'a']
# {'a': 690, 'c': 10, 'b': 10, 'd': 64}
# 6
# ['cpy', '0', 'c']
# {'a': 690, 'c': 0, 'b': 10, 'd': 64}
# 7
# ['jnz', 'c', '-2']
# {'a': 690, 'c': 0, 'b': 10, 'd': 64}
# 8
# ['dec', 'd']
# {'a': 690, 'c': 0, 'b': 10, 'd': 63}
# {'a': 690, 'c': 0, 'b': 10, 'd': 63}
